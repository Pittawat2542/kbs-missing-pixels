# %% [markdown]
# # Prepare Required Dependencies

# %%
from tensorflow.keras.models import load_model
from utils import *

# %%
# Suppress warnings
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Models

# %%
mlp_model_path = "models/model.mlp.h5"
cnn_model_path = "models/model.cnn.h5"
mobilenet_model_path = "models/model.mobilenet.h5"

mlp_imagenet_model_path = "models/model.mlp.imagenet.h5"
cnn_imagenet_model_path = "models/model.cnn.imagenet.h5"
mobilenet_imagenet_model_path = "models/model.mobilenet.imagenet.h5"

mlp_large_imagenet_model_path = "models/model.mlp.large.imagenet.h5"
mlp_full_imagenet_model_path = "models/model.mlp.full.imagenet.h5"

# %%
mlp_model = load_model(mlp_model_path)
cnn_model = load_model(cnn_model_path)
mobilenet_model = load_model(mobilenet_model_path)

mlp_imagenet_model = load_model(mlp_imagenet_model_path)
cnn_imagenet_model = load_model(cnn_imagenet_model_path)
mobilenet_imagenet_model = load_model(mobilenet_imagenet_model_path)

mlp_large_imagenet_model = load_model(mlp_large_imagenet_model_path)
mlp_full_imagenet_model = load_model(mlp_full_imagenet_model_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# # Evaluation

# %%
evaluate_mlp(mlp_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 22.09
# 2023-07-20 16:58:10.657168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(cnn_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 13.61
# 2023-07-20 16:58:10.884342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(mobilenet_model)
# Out:
# 2023-07-20 16:58:11.216341: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/32 [==============================] - 1s 8ms/step
# MSE = 15.65

# %%
evaluate_mlp(mlp_imagenet_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 23.61
# 2023-07-20 16:58:12.541439: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(cnn_imagenet_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 13.90
# 2023-07-20 16:58:12.971350: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(mobilenet_imagenet_model)
# Out:
# 2023-07-20 16:58:13.301209: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/32 [==============================] - 1s 8ms/step
# MSE = 17.04

# %%
evaluate_mlp(mlp_large_imagenet_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 64.22

# %%
evaluate_mlp(mlp_full_imagenet_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 446.78
# 2023-07-20 17:06:13.765917: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
inpainting_image_path = 'images/inpainting_output.png'
evaluate_from_image(inpainting_image_path)
# Out:
# MSE = 312.80
