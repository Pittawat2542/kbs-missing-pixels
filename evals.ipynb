# %% [markdown]
# # Prepare Required Dependencies

# %%
from tensorflow.keras.models import load_model
from utils import *

# %%
# Suppress warnings
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Models

# %%
mlp_model_path = "models/model.mlp.h5"
cnn_model_path = "models/model.cnn.h5"
mobilenet_model_path = "models/model.mobilenet.h5"

# %%
mlp_model = load_model(mlp_model_path)
cnn_model = load_model(cnn_model_path)
mobilenet_model = load_model(mobilenet_model_path)
# Out:
# 2023-07-20 13:15:09.531889: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2023-07-20 13:15:09.531903: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2023-07-20 13:15:09.531906: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2023-07-20 13:15:09.531938: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-20 13:15:09.531951: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Evaluation

# %%
evaluate_mlp(mlp_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 21.57
# 2023-07-20 13:15:11.155305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(cnn_model)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# MSE = 13.61
# 2023-07-20 13:15:11.382675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
evaluate_cnn(mobilenet_model)
# Out:
# 2023-07-20 13:15:11.716766: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/32 [==============================] - 1s 8ms/step
# MSE = 15.65

# %%
inpainting_image_path = 'images/inpainting_output.png'
evaluate_from_image(inpainting_image_path)
# Out:
# MSE = 312.80
